# %% [markdown]
# # 🧠 ECLASS Code Mapping with Fuzzy Matching (RapidFuzz & Levenshtein)
#
# This notebook demonstrates how to match and migrate ECLASS classification codes between versions using fuzzy string matching techniques like Levenshtein distance and RapidFuzz.

# %%
from rapidfuzz import process, distance

# %%
import pandas as pd

# %%
from nltk.tokenize import word_tokenize

# %%
import os

# %%
import re

# %%
import numpy as np

# %% [markdown]
# ## Upload and Standartize your data

# %%
# Insert file path to your products and/or eclasses of interest
# "R:\doc\Kunden Produktlisten\!_current working file\working_files_JAN 2025\EURproductCatalogExpanded.xls"

my_catalog_file = pd.read_excel(input('Paste file path: '))

# %%
eclass_n_1 = pd.read_excel(my_catalog_file)

# %%
def detect_eclass_columns(eclass_n_1):
    eclass_pattern = re.compile(r'^\d{2}(-\d{2}){1,3}$|^\d{8}$')
    candidate_cols = []

    for col in eclass_n_1.columns:
        col_lower = col.lower()
        name_match = any(keyword in col_lower for keyword in ["eclass", "ecl@ss"])

        sample = eclass_n_1[col].dropna().astype(str)
        if len(sample) >= 377:
            sample = sample.sample(n=377, random_state=42)

        match_ratio = sample.apply(lambda x: bool(eclass_pattern.match(x))).mean()
        uniqueness_ratio = sample.nunique() / len(sample) if len(sample) > 0 else 0

        probability_score = match_ratio + 0.2 * uniqueness_ratio  # Weight uniqueness modestly

        if probability_score > 0.75 and name_match:
            candidate_cols.append(col)
            print(f"{col}: match = {match_ratio:.2f}, uniqueness = {uniqueness_ratio:.2f}, score = {probability_score:.2f}")

    return candidate_cols

# %%
column_name = detect_eclass_columns(eclass_n_1)

print("Detected ECLASS columns:", column_name)
# Out:
# ECLASS: match = 1.00, uniqueness = 0.03, score = 1.01
# Detected ECLASS columns: ['ECLASS']

# %%
mycat_e = set(eclass_n_1['{}'.format(str(column_name).replace('"','').replace("'",'').replace('[','').replace(']',''))])

# %%
eclass_n_1.head()
# Out:
#    QTYAMOUNT  VOLUMEPRICE  PARTNUM  \
# 0          1        11.32   10125A
# 1          1        12.98   10125H
# 2          1       418.98  10125HG
# 3          1         8.75   10127C
# 4          1        22.23   10128V
#
#                                               PTITLE  CURR  STOCK  \
# 0  Standard SMA905 Multimode Connector, Ø128 µm B...  Euro  318.0
# 1  Hex Nut SMA905 Multimode Connector, Ø128 µm Bo...  Euro   24.0
# 2          Fiber Optic SMA905 Connector Height Gauge  Euro    3.0
# 3  ST/PC Multimode Connector, &#216;127 &#956;m B...  Euro   40.0
# 4  High-Temp., Vacuum-Compatible SMA905 MM Connec...  Euro    6.0
#
#                                         PRODUCTIMAGE  \
# 0   http://www.thorlabs.com/images/small/1046-sm.jpg
# 1  http://www.thorlabs.com/images/small/TTN201753...
# 2  http://www.thorlabs.com/images/small/14004-sm.jpg
# 3  http://www.thorlabs.com/images/small/TTN018640...
# 4  http://www.thorlabs.com/images/small/TTN159010...
#
#                                             PAGELINK UNITS             LEVEL1  \
# 0  http://www.thorlabs.com/newgrouppage9.cfm?obje...  Each  Thorlabs Products
# 1  http://www.thorlabs.com/newgrouppage9.cfm?obje...  Each  Thorlabs Products
# 2  http://www.thorlabs.com/newgrouppage9.cfm?obje...  EACH  Thorlabs Products
# 3  http://www.thorlabs.com/newgrouppage9.cfm?obje...  EACH  Thorlabs Products
# 4  http://www.thorlabs.com/newgrouppage9.cfm?obje...  Each  Thorlabs Products
#
#    ...                            LEVEL5 LEVEL6 LEVEL7 PRODUCTWEIGHT  \
# 0  ...  Multimode Fiber Optic Connectors    NaN    NaN      0.014991
# 1  ...  Multimode Fiber Optic Connectors    NaN    NaN      0.035053
# 2  ...                               NaN    NaN    NaN      0.345988
# 3  ...  Multimode Fiber Optic Connectors    NaN    NaN      0.013999
# 4  ...  Multimode Fiber Optic Connectors    NaN    NaN      0.350531
#
#        BUNIT  UNSPSCCODE    ECLASS  \
# 0  BU_OPTICS    43223310  32020000
# 1  BU_OPTICS    43223310  32020000
# 2  BU_OPTICS    41111614  27061003
# 3  BU_OPTICS    43223310  27069290
# 4  BU_OPTICS    43223310  32020000
#
#                                             KEYWORDS  \
# 0  125 um,125um,128 um,128um,adapt,adapter,adapto...
# 1  125 um,125um,128 um,128um,adapt,adapter,adapto...
# 2  test,depth,check,standard,measure,polishing,po...
# 3  bayonet,connectorization,ferrule,ceramic,127 b...
# 4  304 SS,304 stainless steel,connector,fiber con...
#
#                                           SHORTTITLE  COO
# 0                        SMA 905 Connector: MM 125um  JPN
# 1                                                NaN  JPN
# 2             Fiber Optic SMA Connector Height Gauge  USA
# 3  ST/PC Connector: MM 127um +4/0um, Ceramic Ferrule  MEX
# 4                                                NaN  HKG
#
# [5 rows x 23 columns]

# %%
# which versions are you going to match? e.g. Old: 5.1 and New: 5.1.4

versionX = str(input('Insert old version: '))
versionY = str(input('Insert new version: '))
# Out:
# Insert old version: 5.1
# Insert new version: 6.2

# %% [markdown]
# # File with Old ECLASS Version (X)

# %%
# Insert your file path, sheet name and rows to skip
# 'R://doc//Kunden Produktlisten//XX_ECLASS//5-10 Eclass categories.xlsx'
# 'Tabelle2'
# 3

eclass_n1_kw = pd.read_excel(input('Paste file path to ECLASS version X: '),
                             sheet_name=input('Paste sheet name: '), skiprows=3)

# %%
eclass_n1_kw.columns
# Out:
# Index(['eclass5.1 categorie (PreferredName)', 'ECLASS5.1',
#        'eclass6.0 categorie (PreferredName)', 'ECLASS6.0', 'name difference'],
#       dtype='object')

# %%
eclass_n1_kw.head()
# Out:
#           eclass5.1 categorie (PreferredName)  ECLASS5.1  \
# 0  Machine, device (for special applications)   17000000
# 1                   Food processing machinery   17010000
# 2                            Bakery machinery   17010100
# 3             Bakery machinery (unclassified)   17010190
# 4                             Meat processing   17010200
#
#    eclass6.0 categorie (PreferredName)  ECLASS6.0  name difference
# 0                                  NaN        NaN              NaN
# 1                                  NaN        NaN              NaN
# 2                                  NaN        NaN              NaN
# 3                                  NaN        NaN              NaN
# 4                                  NaN        NaN              NaN

# %%
def find_eclass_and_preferred_columns(df, versionX):
    eclass_col = None
    preferred_col = None

    # Normalize versionX to lowercase string for matching
    versionX = str(versionX)

    for col in df.columns:
        col_lower = col.lower()

        # Check for ECLASS column: name contains 'eclass' or 'ecl@ss' AND versionX, and values are mostly 8-digit numbers
        if any(kw in col_lower for kw in ["eclass", "ecl@ss"]) and versionX in col_lower:
            sample1 = df[col].dropna().astype(str).head(200)
            if sample1.apply(lambda x: bool(re.fullmatch(r'\d{8}', x))).mean() > 0.6:
                eclass_col = col

        # Check for Preferred Value column
        if df[col].dropna().astype(str).map(len).gt(9).mean() > 0.9:
            preferred_col = col

    return eclass_col, preferred_col

# %%
eclass_col, preferred_col = find_eclass_and_preferred_columns(eclass_n1_kw, versionX)

print("ECLASS column:", eclass_col)
print("PreferredName column:", preferred_col)

eclass_n1_kw = eclass_n1_kw.rename(columns={f'{preferred_col}':f'NAME{versionX}'})
eclass_n1_kw = eclass_n1_kw.rename(columns={f'{eclass_col}':f'ECLASS{versionX}'})

eclass_n1_kw.head()
# Out:
# ECLASS column: ECLASS5.1
# PreferredName column: eclass5.1 categorie (PreferredName)
#                                       NAME5.1  ECLASS5.1  \
# 0  Machine, device (for special applications)   17000000
# 1                   Food processing machinery   17010000
# 2                            Bakery machinery   17010100
# 3             Bakery machinery (unclassified)   17010190
# 4                             Meat processing   17010200
#
#    eclass6.0 categorie (PreferredName)  ECLASS6.0  name difference
# 0                                  NaN        NaN              NaN
# 1                                  NaN        NaN              NaN
# 2                                  NaN        NaN              NaN
# 3                                  NaN        NaN              NaN
# 4                                  NaN        NaN              NaN

# %%
eclass_n1_kw = eclass_n1_kw[eclass_n1_kw['ECLASS5.1'].isin(set(eclass_n_1.ECLASS))]

# %%
eclass_n1_kw.shape
# Out:
# (22, 5)

# %%
# delete all columns ecxept ECLASS number and NAME

for col in eclass_n1_kw.columns:
    if col.startswith('ECLASS{}'.format(versionX)):
        pass
    elif col.startswith('NAME{}'.format(versionX)):
        pass
    else:
        eclass_n1_kw = eclass_n1_kw.drop(columns=col)
        print(col, ' deleted')
# Out:
# eclass6.0 categorie (PreferredName)  deleted
# ECLASS6.0  deleted
# name difference  deleted

# %%
eclass_n1_kw[f'Tokens{versionX}'] = eclass_n1_kw[f'NAME{versionX}'].apply(lambda x: re.findall(r'\w+', x))

# %%
eclass_n1_kw
# Out:
#                                                  NAME5.1  ECLASS5.1  \
# 2693            Measuring tool (surveying, unclassified)   21160190
# 2796                    Measuring machine (unclassified)   21170590
# 3979                       Screw (special, unclassified)   23110690
# 4570                                   PVC adhesive tape   23330201
# 8046                                        Power supply   27040000
# 8116                      Fiber-optic duplex patch cable   27061003
# 8121                                       Coaxial cable   27061802
# 8122                                   Fibre optic cable   27061803
# 8159             Cable, line (accessories, unclassified)   27069290
# 8278                                          LED-module   27110635
# 8279                                                 LED   27110636
# 9064           Wattmeter (electr., handheld meas. appl.)   27200307
# 9158                               Piezoresistive sensor   27201304
# 9276                Command-, control-, signal appliance   27230218
# 9608                                 Semiconductor comp.   27260801
# 9655                                Optical fiber sensor   27270905
# 9690                        Safety-related light curtain   27272704
# 13448                          Equipment, fittings (lab)   32020000
# 13449                          Equipment, fittings (lab)   32020100
# 13452                                   Laboratory table   32020103
# 13926  Consumable material (other, laboratory, unclas...   32039090
# 17402                   Laser beam source (machine tool)   36610408
#
#                                                Tokens5.1
# 2693          [Measuring, tool, surveying, unclassified]
# 2796                  [Measuring, machine, unclassified]
# 3979                      [Screw, special, unclassified]
# 4570                               [PVC, adhesive, tape]
# 8046                                     [Power, supply]
# 8116                [Fiber, optic, duplex, patch, cable]
# 8121                                    [Coaxial, cable]
# 8122                               [Fibre, optic, cable]
# 8159            [Cable, line, accessories, unclassified]
# 8278                                       [LED, module]
# 8279                                               [LED]
# 9064           [Wattmeter, electr, handheld, meas, appl]
# 9158                            [Piezoresistive, sensor]
# 9276               [Command, control, signal, appliance]
# 9608                               [Semiconductor, comp]
# 9655                            [Optical, fiber, sensor]
# 9690                   [Safety, related, light, curtain]
# 13448                         [Equipment, fittings, lab]
# 13449                         [Equipment, fittings, lab]
# 13452                                [Laboratory, table]
# 13926  [Consumable, material, other, laboratory, uncl...
# 17402               [Laser, beam, source, machine, tool]

# %% [markdown]
# ## File with New ECLASS Version

# %%
fileY = r"{}".format(input('Paste file path for target version of ECLASS csv: '))

# %%
eclass_n2_kw = pd.read_csv(fileY, 
    delimiter=';'
)
# Out:
# C:\Users\hahafonova\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (8,11,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
eclass_n2_kw.columns
# Out:
# Index(['supplier', 'idcl', 'identifier', 'version number', 'publication date',
#        'revision number', 'coded name', 'preferred name', 'definition',
#        'iso language code', 'iso country code', 'note', 'remark', 'level',
#        'mksubklass', 'mksynonym', 'mkbsa', 'IRDI_CC', 'type of SE',
#        'correction'],
#       dtype='object')

# %%
def find_eclass_and_keywords(df, versionY):
    class_col = None
    keyword_col = None

    # Normalize versionY to lowercase string for matching
    versionY = str(versionY)

    for col in df.columns:
        col_lower = col.lower()

        # Check for ECLASS column: name contains 'eclass' or 'ecl@ss' AND versionX, and values are mostly 8-digit numbers
        if any(kw in col_lower for kw in ["class", "coded"]) or versionY in col_lower:
            sample = df[col].dropna().astype(str).head(20)
            if sample.apply(lambda x: bool(re.fullmatch(r'\d{8}', x))).mean() > 0.6:
                class_col = col

        # Check for Preferred Value column
        if df[col].dropna().astype(str).map(len).gt(10).mean() > 0.9 and all(kw in col_lower for kw in ["preferred name"]):
            keyword_col = col

    return class_col, keyword_col

# %%
class_col, keyword_col = find_eclass_and_keywords(eclass_n2_kw, versionY)

print("ECLASS column:", class_col)
print("Key Word column:", keyword_col)

eclass_n2_kw = eclass_n2_kw.rename(columns={f'{keyword_col}':f'NAME{versionY}'})
eclass_n2_kw = eclass_n2_kw.rename(columns={f'{class_col}':f'ECLASS{versionY}'})

eclass_n2_kw.head()
# Out:
# ECLASS column: coded name
# Key Word column: preferred name
#   supplier       idcl identifier  version number publication date  \
# 0   0173-1  ACE546002     ACE546               2       2008-12-03
# 1   0173-1  ACE547002     ACE547               2       2008-12-03
# 2   0173-1  ACE561002     ACE561               2       2008-12-03
# 3   0173-1  ACE794004     ACE794               4       2009-11-28
# 4   0173-1  ACE796004     ACE796               4       2009-11-28
#
#    revision number  ECLASS6.2                  NAME6.2 definition  \
# 0                1   16000000  Food, beverage, tobacco        NaN
# 1                1   16010000            Cereal, pulse        NaN
# 2                1   16010100                   Cereal        NaN
# 3                1   16010101                   Barley        NaN
# 4                1   16010102                      Oat        NaN
#
#   iso language code iso country code note remark  level  mksubklass mksynonym  \
# 0                en               EN  NaN    NaN      1           1       NaN
# 1                en               EN  NaN    NaN      2           1       NaN
# 2                en               EN  NaN    NaN      3           1       NaN
# 3                en               EN  NaN    NaN      4           0       NaN
# 4                en               EN  NaN    NaN      4           0       NaN
#
#    mkbsa               IRDI_CC  type of SE  correction
# 0    NaN  0173-1#01-ACE546#002           1       False
# 1    NaN  0173-1#01-ACE547#002           1       False
# 2    NaN  0173-1#01-ACE561#002           1       False
# 3    NaN  0173-1#01-ACE794#004           1       False
# 4    NaN  0173-1#01-ACE796#004           1       False

# %%
# delete all columns ecxept ECLASS number and NAME

for col in eclass_n2_kw.columns:
    if col.startswith('ECLASS{}'.format(versionY)):
        pass
    elif col.startswith('NAME{}'.format(versionY)):
        pass
    else:
        eclass_n2_kw = eclass_n2_kw.drop(columns=col)
        print(col, ' deleted')
# Out:
# supplier  deleted
# idcl  deleted
# identifier  deleted
# version number  deleted
# publication date  deleted
# revision number  deleted
# definition  deleted
# iso language code  deleted
# iso country code  deleted
# note  deleted
# remark  deleted
# level  deleted
# mksubklass  deleted
# mksynonym  deleted
# mkbsa  deleted
# IRDI_CC  deleted
# type of SE  deleted
# correction  deleted

# %%
eclass_n2_kw
# Out:
#        ECLASS6.2                                    NAME6.2
# 0       16000000                    Food, beverage, tobacco
# 1       16010000                              Cereal, pulse
# 2       16010100                                     Cereal
# 3       16010101                                     Barley
# 4       16010102                                        Oat
# ...          ...                                        ...
# 32827   41149090  Services (marketing, other, unclassified)
# 32828   90000000               Interim class (unclassified)
# 32829   90900000       Interim classification (unspecified)
# 32830   90909000       Interim classification (unspecified)
# 32831   90909090       Interim classification (unspecified)
#
# [32832 rows x 2 columns]

# %%
# delete all columns ecxept ECLASS number and NAME

for col in eclass_n2_kw.columns:
    if col.startswith('ECLASS{}'.format(versionY)):
        pass
    elif col.startswith('NAME{}'.format(versionY)):
        pass
    else:
        eclass_n2_kw = eclass_n2_kw.drop(columns=col)
        print(col, ' deleted')

# %%
eclass_n2_kw
# Out:
#        ECLASS6.2                                    NAME6.2
# 0       16000000                    Food, beverage, tobacco
# 1       16010000                              Cereal, pulse
# 2       16010100                                     Cereal
# 3       16010101                                     Barley
# 4       16010102                                        Oat
# ...          ...                                        ...
# 32827   41149090  Services (marketing, other, unclassified)
# 32828   90000000               Interim class (unclassified)
# 32829   90900000       Interim classification (unspecified)
# 32830   90909000       Interim classification (unspecified)
# 32831   90909090       Interim classification (unspecified)
#
# [32832 rows x 2 columns]

# %%
eclass_n2_kw[f'Tokens{versionY}'] = eclass_n2_kw[f'NAME{versionY}'].apply(lambda x: re.findall(r'\w+', x))

# %%
eclass_n2_kw
# Out:
#        ECLASS6.2                                    NAME6.2  \
# 0       16000000                    Food, beverage, tobacco
# 1       16010000                              Cereal, pulse
# 2       16010100                                     Cereal
# 3       16010101                                     Barley
# 4       16010102                                        Oat
# ...          ...                                        ...
# 32827   41149090  Services (marketing, other, unclassified)
# 32828   90000000               Interim class (unclassified)
# 32829   90900000       Interim classification (unspecified)
# 32830   90909000       Interim classification (unspecified)
# 32831   90909090       Interim classification (unspecified)
#
#                                         Tokens6.2
# 0                       [Food, beverage, tobacco]
# 1                                 [Cereal, pulse]
# 2                                        [Cereal]
# 3                                        [Barley]
# 4                                           [Oat]
# ...                                           ...
# 32827  [Services, marketing, other, unclassified]
# 32828              [Interim, class, unclassified]
# 32829      [Interim, classification, unspecified]
# 32830      [Interim, classification, unspecified]
# 32831      [Interim, classification, unspecified]
#
# [32832 rows x 3 columns]

# %% [markdown]
# ## RAPIDFUZZ

# %%
n = input('Select number of candidates pro each ECLASS')

# %%
# Function to find top 3 matches along with their ECLASS514 values
def find_top_matches_with_eclass(token51, table2):
    matches = process.extract(token51, table2[f'Tokens{versionY}'], limit=n)  # Get top N matches
    # Append the corresponding eclass value to the matches
    detailed_matches = [
        (match[0], match[1], match[2], table2.iloc[match[2]][f'ECLASS{versionY}'])  
        for match in matches
    ]
    return detailed_matches

eclass_n1_kw['TopNMatches'] = eclass_n1_kw[f'Tokens{versionX}'].apply(lambda x: find_top_matches_with_eclass(x, eclass_n2_kw))

# Print the results
for index, row in eclass_n1_kw.iterrows():
    print(f"ECLASS {versionX}: {row[f'ECLASS{versionX}']} - {row[f'Tokens{versionX}']} - Top N Matches:")
    for match in row['TopNMatches']:
        print(f"  Match: {match[0]}, Score: {match[1]:.2f}, ECLASS{versionY}: {match[3]}")
# Out:
# ECLASS 5.1: 21160190 - ['Measuring', 'tool', 'surveying', 'unclassified'] - Top 3 Matches:
#   Match: ['Measuring', 'tool', 'surveying', 'unclassified'], Score: 100.00, ECLASS6.2: 21160190
#   Match: ['Measuring', 'tool'], Score: 90.00, ECLASS6.2: 21170600
#   Match: ['Measuring', 'tool', 'unclassified'], Score: 85.71, ECLASS6.2: 21170690
# ECLASS 5.1: 21170590 - ['Measuring', 'machine', 'unclassified'] - Top 3 Matches:
#   Match: ['Measuring', 'machine', 'unclassified'], Score: 100.00, ECLASS6.2: 21170590
#   Match: ['Measuring', 'machine'], Score: 90.00, ECLASS6.2: 21170500
#   Match: ['Doubling', 'twisting', 'winding', 'reeling', 'machine', 'unclassified'], Score: 72.00, ECLASS6.2: 17020890
# ECLASS 5.1: 23110690 - ['Screw', 'special', 'unclassified'] - Top 3 Matches:
#   Match: ['Screw', 'special', 'unclassified'], Score: 100.00, ECLASS6.2: 23110690
#   Match: ['Screw', 'special'], Score: 90.00, ECLASS6.2: 23110600
#   Match: ['Nut', 'special', 'unclassified'], Score: 66.67, ECLASS6.2: 23110890
# ECLASS 5.1: 23330201 - ['PVC', 'adhesive', 'tape'] - Top 3 Matches:
#   Match: ['PVC', 'adhesive', 'tape'], Score: 100.00, ECLASS6.2: 23330201
#   Match: ['Condom', 'urinal', 'with', 'adhesive', 'tape'], Score: 72.00, ECLASS6.2: 34380302
#   Match: ['Polyester', 'adhesive', 'tape'], Score: 66.67, ECLASS6.2: 23330202
# ECLASS 5.1: 27040000 - ['Power', 'supply'] - Top 3 Matches:
#   Match: ['Power', 'supply'], Score: 100.00, ECLASS6.2: 27040000
#   Match: ['Power', 'supply', 'computer', 'module'], Score: 90.00, ECLASS6.2: 19051000
#   Match: ['Power', 'supply', 'computer', 'module'], Score: 90.00, ECLASS6.2: 19051001
# ECLASS 5.1: 27061003 - ['Fiber', 'optic', 'duplex', 'patch', 'cable'] - Top 3 Matches:
#   Match: ['Fiber', 'optic', 'duplex', 'patch', 'cable'], Score: 100.00, ECLASS6.2: 27061003
#   Match: ['Fiber', 'optic', 'cable'], Score: 75.00, ECLASS6.2: 27061803
#   Match: ['Band', 'cable'], Score: 60.00, ECLASS6.2: 23170600
# ECLASS 5.1: 27061802 - ['Coaxial', 'cable'] - Top 3 Matches:
#   Match: ['Coaxial', 'cable'], Score: 100.00, ECLASS6.2: 27061802
#   Match: ['Wire', 'rope', 'clamp', 'steel', 'cable'], Score: 60.00, ECLASS6.2: 23130106
#   Match: ['Ready', 'made', 'data', 'cable'], Score: 60.00, ECLASS6.2: 27060300
# ECLASS 5.1: 27061803 - ['Fibre', 'optic', 'cable'] - Top 3 Matches:
#   Match: ['Fiber', 'optic', 'cable'], Score: 66.67, ECLASS6.2: 27061803
#   Match: ['Band', 'cable'], Score: 60.00, ECLASS6.2: 23170600
#   Match: ['Bus', 'cable'], Score: 60.00, ECLASS6.2: 27060307
# ECLASS 5.1: 27069290 - ['Cable', 'line', 'accessories', 'unclassified'] - Top 3 Matches:
#   Match: ['Cable', 'line', 'accessories', 'unclassified'], Score: 100.00, ECLASS6.2: 27069290
#   Match: ['Cable'], Score: 90.00, ECLASS6.2: 23170601
#   Match: ['Cable', 'line', 'accessories'], Score: 85.71, ECLASS6.2: 27069200
# ECLASS 5.1: 27110635 - ['LED', 'module'] - Top 3 Matches:
#   Match: ['LED', 'module'], Score: 100.00, ECLASS6.2: 27110635
#   Match: ['LED'], Score: 90.00, ECLASS6.2: 27110636
#   Match: ['Interface', 'card', 'computer', 'module'], Score: 60.00, ECLASS6.2: 19050100
# ECLASS 5.1: 27110636 - ['LED'] - Top 3 Matches:
#   Match: ['LED'], Score: 100.00, ECLASS6.2: 27110636
#   Match: ['LED', 'module'], Score: 90.00, ECLASS6.2: 27110635
#   Match: ['Multi', 'LED'], Score: 90.00, ECLASS6.2: 27110640
# ECLASS 5.1: 27200307 - ['Wattmeter', 'electr', 'handheld', 'meas', 'appl'] - Top 3 Matches:
#   Match: ['Wattmeter', 'electr', 'handheld', 'meas', 'appl'], Score: 100.00, ECLASS6.2: 27200307
#   Match: ['Screwdriver', 'electr'], Score: 45.00, ECLASS6.2: 21050800
#   Match: ['Shears', 'electr'], Score: 45.00, ECLASS6.2: 21050900
# ECLASS 5.1: 27201304 - ['Piezoresistive', 'sensor'] - Top 3 Matches:
#   Match: ['Piezoresistive', 'sensor'], Score: 100.00, ECLASS6.2: 27201304
#   Match: ['Piezoresistive', 'sensor', 'abs', 'and', 'rel', 'pressure'], Score: 90.00, ECLASS6.2: 27201301
#   Match: ['Coupling', 'with', 'measuring', 'sensor'], Score: 60.00, ECLASS6.2: 23031800
# ECLASS 5.1: 27230218 - ['Command', 'control', 'signal', 'appliance'] - Top 3 Matches:
#   Match: ['Command', 'control', 'signal', 'appliance'], Score: 100.00, ECLASS6.2: 27230218
#   Match: ['Connector', 'appliance'], Score: 60.00, ECLASS6.2: 27143424
#   Match: ['Command', 'panel'], Score: 60.00, ECLASS6.2: 27180505
# ECLASS 5.1: 27260801 - ['Semiconductor', 'comp'] - Top 3 Matches:
#   Match: ['Mass', 'storage', 'comp', 'proc', 'comp'], Score: 60.00, ECLASS6.2: 27230227
#   Match: ['Monitoring', 'comp', 'proc', 'comp'], Score: 60.00, ECLASS6.2: 27230228
#   Match: ['Interface', 'proc', 'comp'], Score: 60.00, ECLASS6.2: 27230229
# ECLASS 5.1: 27270905 - ['Optical', 'fiber', 'sensor'] - Top 3 Matches:
#   Match: ['Optical', 'fiber', 'sensor'], Score: 100.00, ECLASS6.2: 27270905
#   Match: ['Optical', 'fiber', 'pigtail'], Score: 66.67, ECLASS6.2: 27061002
#   Match: ['Optical', 'fiber', 'sleeve'], Score: 66.67, ECLASS6.2: 27069212
# ECLASS 5.1: 27272704 - ['Safety', 'related', 'light', 'curtain'] - Top 3 Matches:
#   Match: ['Safety', 'related', 'light', 'curtain'], Score: 100.00, ECLASS6.2: 27272704
#   Match: ['Safety', 'related', 'irradiating', 'light', 'barrier'], Score: 66.67, ECLASS6.2: 27272701
#   Match: ['Safety', 'related', 'reflection', 'light', 'barrier'], Score: 66.67, ECLASS6.2: 27272702
# ECLASS 5.1: 32020000 - ['Equipment', 'fittings', 'lab'] - Top 3 Matches:
#   Match: ['Equipment', 'fittings', 'lab'], Score: 100.00, ECLASS6.2: 32020100
#   Match: ['Equipment', 'fittings', 'lab', 'unclassified'], Score: 85.71, ECLASS6.2: 32020190
#   Match: ['Cupboard', 'lab'], Score: 60.00, ECLASS6.2: 32020500
# ECLASS 5.1: 32020100 - ['Equipment', 'fittings', 'lab'] - Top 3 Matches:
#   Match: ['Equipment', 'fittings', 'lab'], Score: 100.00, ECLASS6.2: 32020100
#   Match: ['Equipment', 'fittings', 'lab', 'unclassified'], Score: 85.71, ECLASS6.2: 32020190
#   Match: ['Cupboard', 'lab'], Score: 60.00, ECLASS6.2: 32020500
# ECLASS 5.1: 32020103 - ['Laboratory', 'table'] - Top 3 Matches:
#   Match: ['Laboratory', 'table'], Score: 100.00, ECLASS6.2: 32020103
#   Match: ['Lowering', 'the', 'water', 'table'], Score: 60.00, ECLASS6.2: 22100801
#   Match: ['Linear', 'motion', 'table'], Score: 60.00, ECLASS6.2: 23301500
# ECLASS 5.1: 32039090 - ['Consumable', 'material', 'other', 'laboratory', 'unclassified'] - Top 3 Matches:
#   Match: ['Dosing', 'aid', 'removal', 'aid', 'packing', 'material', 'other', 'unclassified'], Score: 67.50, ECLASS6.2: 20399090
#   Match: ['Pipe', 'and', 'pipe', 'fitting', 'building', 'material', 'other', 'unclassified'], Score: 67.50, ECLASS6.2: 22149090
#   Match: ['Equipment', 'for', 'odd', 'lot', 'storage', 'hazardous', 'material', 'other', 'unclassified'], Score: 67.50, ECLASS6.2: 40069090
# ECLASS 5.1: 36610408 - ['Laser', 'beam', 'source', 'machine', 'tool'] - Top 3 Matches:
#   Match: ['Laser', 'beam', 'source', 'machine', 'tool'], Score: 100.00, ECLASS6.2: 36610408
#   Match: ['Thermal', 'beam', 'processing', 'system', 'a', 'beam', 'source', 'machine', 'tool'], Score: 80.00, ECLASS6.2: 36610400
#   Match: ['Cutting', 'machine', 'tool'], Score: 72.00, ECLASS6.2: 36600000

# %%
for e in eclass_n1_kw['TopNMatches']:
    print(e[0][-1])
# Out:
# 21160190
# 21170590
# 23110690
# 23330201
# 27040000
# 27061003
# 27061802
# 27061803
# 27069290
# 27110635
# 27110636
# 27200307
# 27201304
# 27230218
# 27230227
# 27270905
# 27272704
# 32020100
# 32020100
# 32020103
# 20399090
# 36610408

# %%
eclass_n1_kw.shape
# Out:
# (22, 4)

# %%
df = eclass_n1_kw.explode('TopNMatches')

# %%
df
# Out:
#                                                  NAME5.1  ECLASS5.1  \
# 2693            Measuring tool (surveying, unclassified)   21160190
# 2693            Measuring tool (surveying, unclassified)   21160190
# 2693            Measuring tool (surveying, unclassified)   21160190
# 2796                    Measuring machine (unclassified)   21170590
# 2796                    Measuring machine (unclassified)   21170590
# ...                                                  ...        ...
# 13926  Consumable material (other, laboratory, unclas...   32039090
# 13926  Consumable material (other, laboratory, unclas...   32039090
# 17402                   Laser beam source (machine tool)   36610408
# 17402                   Laser beam source (machine tool)   36610408
# 17402                   Laser beam source (machine tool)   36610408
#
#                                                Tokens5.1  \
# 2693          [Measuring, tool, surveying, unclassified]
# 2693          [Measuring, tool, surveying, unclassified]
# 2693          [Measuring, tool, surveying, unclassified]
# 2796                  [Measuring, machine, unclassified]
# 2796                  [Measuring, machine, unclassified]
# ...                                                  ...
# 13926  [Consumable, material, other, laboratory, uncl...
# 13926  [Consumable, material, other, laboratory, uncl...
# 17402               [Laser, beam, source, machine, tool]
# 17402               [Laser, beam, source, machine, tool]
# 17402               [Laser, beam, source, machine, tool]
#
#                                              Top3Matches
# 2693   ([Measuring, tool, surveying, unclassified], 1...
# 2693           ([Measuring, tool], 90.0, 4423, 21170600)
# 2693   ([Measuring, tool, unclassified], 85.714285714...
# 2796   ([Measuring, machine, unclassified], 100.0, 44...
# 2796        ([Measuring, machine], 90.0, 4403, 21170500)
# ...                                                  ...
# 13926  ([Pipe, and, pipe, fitting, building, material...
# 13926  ([Equipment, for, odd, lot, storage, hazardous...
# 17402  ([Laser, beam, source, machine, tool], 100.0, ...
# 17402  ([Thermal, beam, processing, system, a, beam, ...
# 17402  ([Cutting, machine, tool], 72.0, 23785, 36600000)
#
# [66 rows x 4 columns]

# %%
df['Match_keyword'] = df['TopNMatches'].apply(lambda e: e[0]).apply(lambda x : ' '.join(x))

# %%
df
# Out:
#                                                  NAME5.1  ECLASS5.1  \
# 2693            Measuring tool (surveying, unclassified)   21160190
# 2693            Measuring tool (surveying, unclassified)   21160190
# 2693            Measuring tool (surveying, unclassified)   21160190
# 2796                    Measuring machine (unclassified)   21170590
# 2796                    Measuring machine (unclassified)   21170590
# ...                                                  ...        ...
# 13926  Consumable material (other, laboratory, unclas...   32039090
# 13926  Consumable material (other, laboratory, unclas...   32039090
# 17402                   Laser beam source (machine tool)   36610408
# 17402                   Laser beam source (machine tool)   36610408
# 17402                   Laser beam source (machine tool)   36610408
#
#                                                Tokens5.1  \
# 2693          [Measuring, tool, surveying, unclassified]
# 2693          [Measuring, tool, surveying, unclassified]
# 2693          [Measuring, tool, surveying, unclassified]
# 2796                  [Measuring, machine, unclassified]
# 2796                  [Measuring, machine, unclassified]
# ...                                                  ...
# 13926  [Consumable, material, other, laboratory, uncl...
# 13926  [Consumable, material, other, laboratory, uncl...
# 17402               [Laser, beam, source, machine, tool]
# 17402               [Laser, beam, source, machine, tool]
# 17402               [Laser, beam, source, machine, tool]
#
#                                              Top3Matches  \
# 2693   ([Measuring, tool, surveying, unclassified], 1...
# 2693           ([Measuring, tool], 90.0, 4423, 21170600)
# 2693   ([Measuring, tool, unclassified], 85.714285714...
# 2796   ([Measuring, machine, unclassified], 100.0, 44...
# 2796        ([Measuring, machine], 90.0, 4403, 21170500)
# ...                                                  ...
# 13926  ([Pipe, and, pipe, fitting, building, material...
# 13926  ([Equipment, for, odd, lot, storage, hazardous...
# 17402  ([Laser, beam, source, machine, tool], 100.0, ...
# 17402  ([Thermal, beam, processing, system, a, beam, ...
# 17402  ([Cutting, machine, tool], 72.0, 23785, 36600000)
#
#                                            Match_keyword
# 2693               Measuring tool surveying unclassified
# 2693                                      Measuring tool
# 2693                         Measuring tool unclassified
# 2796                      Measuring machine unclassified
# 2796                                   Measuring machine
# ...                                                  ...
# 13926  Pipe and pipe fitting building material other ...
# 13926  Equipment for odd lot storage hazardous materi...
# 17402                     Laser beam source machine tool
# 17402  Thermal beam processing system a beam source m...
# 17402                               Cutting machine tool
#
# [66 rows x 5 columns]

# %%
df['Match_Score'] = df['TopNMatches'].apply(lambda e : e[1]).astype(int)

# %%
df['ECLASS_n'] = df['TopNMatches'].apply(lambda e : e[-1])

# %%
df.head(20)
# Out:
#                                        NAME5.1  ECLASS5.1  \
# 2693  Measuring tool (surveying, unclassified)   21160190
# 2693  Measuring tool (surveying, unclassified)   21160190
# 2693  Measuring tool (surveying, unclassified)   21160190
# 2796          Measuring machine (unclassified)   21170590
# 2796          Measuring machine (unclassified)   21170590
# 2796          Measuring machine (unclassified)   21170590
# 3979             Screw (special, unclassified)   23110690
# 3979             Screw (special, unclassified)   23110690
# 3979             Screw (special, unclassified)   23110690
# 4570                         PVC adhesive tape   23330201
# 4570                         PVC adhesive tape   23330201
# 4570                         PVC adhesive tape   23330201
# 8046                              Power supply   27040000
# 8046                              Power supply   27040000
# 8046                              Power supply   27040000
# 8116            Fiber-optic duplex patch cable   27061003
# 8116            Fiber-optic duplex patch cable   27061003
# 8116            Fiber-optic duplex patch cable   27061003
# 8121                             Coaxial cable   27061802
# 8121                             Coaxial cable   27061802
#
#                                        Tokens5.1  \
# 2693  [Measuring, tool, surveying, unclassified]
# 2693  [Measuring, tool, surveying, unclassified]
# 2693  [Measuring, tool, surveying, unclassified]
# 2796          [Measuring, machine, unclassified]
# 2796          [Measuring, machine, unclassified]
# 2796          [Measuring, machine, unclassified]
# 3979              [Screw, special, unclassified]
# 3979              [Screw, special, unclassified]
# 3979              [Screw, special, unclassified]
# 4570                       [PVC, adhesive, tape]
# 4570                       [PVC, adhesive, tape]
# 4570                       [PVC, adhesive, tape]
# 8046                             [Power, supply]
# 8046                             [Power, supply]
# 8046                             [Power, supply]
# 8116        [Fiber, optic, duplex, patch, cable]
# 8116        [Fiber, optic, duplex, patch, cable]
# 8116        [Fiber, optic, duplex, patch, cable]
# 8121                            [Coaxial, cable]
# 8121                            [Coaxial, cable]
#
#                                             Top3Matches  \
# 2693  ([Measuring, tool, surveying, unclassified], 1...
# 2693          ([Measuring, tool], 90.0, 4423, 21170600)
# 2693  ([Measuring, tool, unclassified], 85.714285714...
# 2796  ([Measuring, machine, unclassified], 100.0, 44...
# 2796       ([Measuring, machine], 90.0, 4403, 21170500)
# 2796  ([Doubling, twisting, winding, reeling, machin...
# 3979  ([Screw, special, unclassified], 100.0, 6784, ...
# 3979           ([Screw, special], 90.0, 6780, 23110600)
# 3979  ([Nut, special, unclassified], 66.666666666666...
# 4570     ([PVC, adhesive, tape], 100.0, 7482, 23330201)
# 4570  ([Condom, urinal, with, adhesive, tape], 72.0,...
# 4570  ([Polyester, adhesive, tape], 66.6666666666666...
# 8046          ([Power, supply], 100.0, 11280, 27040000)
# 8046  ([Power, supply, computer, module], 90.0, 1219...
# 8046  ([Power, supply, computer, module], 90.0, 1220...
# 8116  ([Fiber, optic, duplex, patch, cable], 100.0, ...
# 8116     ([Fiber, optic, cable], 75.0, 11374, 27061803)
# 8116  ([Band, cable], 60.00000000000001, 6973, 23170...
# 8121         ([Coaxial, cable], 100.0, 11373, 27061802)
# 8121  ([Wire, rope, clamp, steel, cable], 60.0000000...
#
#                                           Match_keyword  Match_Score  ECLASS_n
# 2693              Measuring tool surveying unclassified          100  21160190
# 2693                                     Measuring tool           90  21170600
# 2693                        Measuring tool unclassified           85  21170690
# 2796                     Measuring machine unclassified          100  21170590
# 2796                                  Measuring machine           90  21170500
# 2796  Doubling twisting winding reeling machine uncl...           72  17020890
# 3979                         Screw special unclassified          100  23110690
# 3979                                      Screw special           90  23110600
# 3979                           Nut special unclassified           66  23110890
# 4570                                  PVC adhesive tape          100  23330201
# 4570                   Condom urinal with adhesive tape           72  34380302
# 4570                            Polyester adhesive tape           66  23330202
# 8046                                       Power supply          100  27040000
# 8046                       Power supply computer module           90  19051000
# 8046                       Power supply computer module           90  19051001
# 8116                     Fiber optic duplex patch cable          100  27061003
# 8116                                  Fiber optic cable           75  27061803
# 8116                                         Band cable           60  23170600
# 8121                                      Coaxial cable          100  27061802
# 8121                        Wire rope clamp steel cable           60  23130106

# %%
df.to_excel('{}'.format(input('Paste file path to save extended results')), index=False)

# %% [markdown]
# ## Last Version

# %%
eclass_n1_kw['ECLASS_X'] = eclass_n1_kw['TopNMatches'].apply(
    lambda e : e[0][-1] )

# %%
eclass_n1_kw['Similarity'] = eclass_n1_kw['TopNMatches'].apply(
    lambda e : e[0][1] )

# %%
eclass_n1_kw = pd.merge(eclass_n1_kw, eclass_n2_kw, how='left', on='ECLASS_X')

# %%
eclass_n1_kw.Similarity.max()
# Out:
# 100.0

# %%
eclass_n1_kw.describe()
# Out:
#           ECLASS5.1     ECLASS6.2  Similarity
# count  2.200000e+01  2.200000e+01   22.000000
# mean   2.756513e+07  2.703465e+07   95.189394
# std    3.673591e+06  3.833226e+06   12.456092
# min    2.116019e+07  2.039909e+07   60.000000
# 25%    2.706120e+07  2.704525e+07  100.000000
# 50%    2.715547e+07  2.711064e+07  100.000000
# 75%    2.727225e+07  2.726074e+07  100.000000
# max    3.661041e+07  3.661041e+07  100.000000

# %%
eclass_n1_kw.to_excel('{}'.format(input('Paste path to save matched version')), index=False)
